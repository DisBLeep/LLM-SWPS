# %%
from ourfuncs import *
from main import PATH_LOG_QUERY, PATH_LOG_RESULTS, PATH_LOG_CHATSUMMARY

# %%
PATH_DOCS_EMBEDDED = "Saved/"
print('Zaembedowane dokumenty:')
embedded_docs = [f for f in os.listdir(PATH_DOCS_EMBEDDED) if f.lower().endswith('.pkl')]

for file in embedded_docs:
    # Correcting the file path to use the variable 'file' instead of a hardcoded filename
    print_sample = pd.read_pickle(f"{PATH_DOCS_EMBEDDED}{file}")
    
    # Using .tail() to print the bottom 5 entries
    print(f"Ostatnie 5 wpisów w pliku {file}:")
    display(print_sample.tail())  # Using display() for better formatting in Jupyter Notebooks

    # Optionally, if you want to print the file name after displaying the data (less logical in this context)
    # print(file)
# Out:
# Zaembedowane dokumenty:
# Ostatnie 5 wpisów w pliku kodeks_karny.pkl:
#                   File  Page  Sentence Index  \
# 1403  kodeks_karny.pdf   126               6
# 1404  kodeks_karny.pdf   126               7
# 1405  kodeks_karny.pdf   126               8
# 1406  kodeks_karny.pdf   126               9
# 1407  kodeks_karny.pdf   127               1
#
#                                                Sentence  \
# 1403  W wypadku mniejszej wagi, sprawca \npodlega gr...
# 1404  Art. 362. § 1. Żołnierz, który samowolnie używ...
# 1405  W wypadku mniejszej wagi, sprawca \npodlega gr...
# 1406  Art. 363. § 1. Żołnierz, który samowolnie rozp...
# 1407  ©Kancelaria Sejmu \n \ns. 127/127 \n25.11.2021...
#
#                                       Embedded Sentence
# 1403  [-0.0005494100041687489, 0.010012708604335785,...
# 1404  [0.0037641662638634443, -0.0112464539706707, -...
# 1405  [0.005404740106314421, 0.005846208427101374, 0...
# ...

# %%
PATH_DOCS_EMBEDDED = "Logs/"
print('Zaembedowane dokumenty:')
embedded_docs = [f for f in os.listdir(PATH_DOCS_EMBEDDED) if f.lower().endswith('.pkl')]

for file in embedded_docs:
    # Correcting the file path to use the variable 'file' instead of a hardcoded filename
    print_sample = pd.read_pickle(f"{PATH_DOCS_EMBEDDED}{file}")
    
    # Using .tail() to print the bottom 5 entries
    print(f"Ostatnie 5 wpisów w pliku {file}:")
    display(print_sample.tail())  # Using display() for better formatting in Jupyter Notebooks

    # Optionally, if you want to print the file name after displaying the data (less logical in this context)
    # print(file)
# Out:
# Zaembedowane dokumenty:
# Ostatnie 5 wpisów w pliku log_chatsummary.pkl:
#                     Timestamp  \
# 38 2024-04-23 20:59:47.546753
# 39 2024-04-23 21:07:44.288866
# 40 2024-04-23 21:11:56.344393
# 41 2024-04-23 21:19:47.439274
# 42 2024-04-23 21:38:28.369808
#
#                                        summary_prompt  \
# 38  Twoim zadaniem jest odpowiedzieć na pytanie uż...
# 39  Twoim zadaniem jest odpowiedzieć na pytanie uż...
# 40  Twoim zadaniem jest odpowiedzieć na pytanie uż...
# 41  Twoim zadaniem jest odpowiedzieć na pytanie uż...
# 42  Twoim zadaniem jest odpowiedzieć na pytanie uż...
#
#                                       found_fragments  \
# 38  (Fragment 1: czerwony-kapturek.pdf Page 2)\n"I...
# 39  (Fragment 1: czerwony-kapturek.pdf Page 2)\n"I...
# 40  (Fragment 1: czerwony-kapturek.pdf Page 2)\n"I...
# 41  (Fragment 1: maly_ksiaze.pdf Page 24)\n"To będ...
# 42  (Fragment 1: maly_ksiaze.pdf Page 50)\n"Lecz z...
#
#                user_query_text  \
# ...
