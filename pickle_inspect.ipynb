# %%
from ourfuncs import *
from main import PATH_LOG_QUERY, PATH_LOG_RESULTS

PATH_DOCS_EMBEDDED = "Saved/"
embedded_docs = [f for f in os.listdir(PATH_DOCS_EMBEDDED) if f.lower().endswith('.pkl')]
for file in embedded_docs:
    print(file)
# Out:
# maly_ksiaze.pkl
# ustawa_o_wlasnosci_mieszkan.pkl

# %%
maly_ksiaze = pd.read_pickle(f"{PATH_DOCS_EMBEDDED}maly_ksiaze.pkl")
maly_ksiaze
# Out:
#                 File  Page  Sentence Index  \
# 0    maly_ksiaze.pdf     1               1
# 1    maly_ksiaze.pdf     1               2
# 2    maly_ksiaze.pdf     1               3
# 3    maly_ksiaze.pdf     1               4
# 4    maly_ksiaze.pdf     1               5
# ..               ...   ...             ...
# 739  maly_ksiaze.pdf    65               1
# 740  maly_ksiaze.pdf    65               2
# 741  maly_ksiaze.pdf    65               3
# 742  maly_ksiaze.pdf    65               4
# 743  maly_ksiaze.pdf    65               5
#
#                                               Sentence  \
# 0    Antoine de Saint-Exupéry \nMały Książę \n \n \...
# 1    Mam ważne ku \ntemu powody: ten dorosły jest m...
# 2    Drugi powód: ten \ndorosły potrafi zrozumieć w...
# 3    Mam też trzeci powód: ten \ndorosły znajduje s...
# 4    Jeśli te \npowody nie wystarczą - chętnie pośw...
# ..                                                 ...
# ...

# %%
maly_ksiaze = pd.read_pickle(f"{PATH_DOCS_EMBEDDED}ustawa_o_wlasnosci_mieszkan.pkl")
maly_ksiaze
# Out:
#                                 File  Page  Sentence Index  \
# 0    ustawa_o_wlasnosci_mieszkan.pdf     1               1
# 1    ustawa_o_wlasnosci_mieszkan.pdf     1               2
# 2    ustawa_o_wlasnosci_mieszkan.pdf     1               3
# 3    ustawa_o_wlasnosci_mieszkan.pdf     1               4
# 4    ustawa_o_wlasnosci_mieszkan.pdf     1               5
# ..                               ...   ...             ...
# 135  ustawa_o_wlasnosci_mieszkan.pdf    14               4
# 136  ustawa_o_wlasnosci_mieszkan.pdf    14               5
# 137  ustawa_o_wlasnosci_mieszkan.pdf    14               6
# 138  ustawa_o_wlasnosci_mieszkan.pdf    15               1
# 139  ustawa_o_wlasnosci_mieszkan.pdf    15               2
#
#                                               Sentence  \
# 0    ©Kancelaria Sejmu \n \n \n \ns. 1/15 \n \n2023...
# 1    Ustawa \nokreśla \nsposób \nustanawiania \nodr...
# 2    W zakresie nieuregulowanym ustawą do własności...
# ...

# %%
log_z_zapytaniami = pd.read_pickle(PATH_LOG_QUERY)
log_z_zapytaniami
# Out:
#                    Timestamp                       User Input  \
# 0 2024-04-13 17:29:09.261860  Czy mały książe tęsknił za różą
# 1 2024-04-13 17:35:46.697537      Jakie są obowiązki zarządu?
# 2 2024-04-13 17:39:29.337243       Czy mały książe był mądry?
# 3 2024-04-13 17:45:48.472021      Czym zajmował się latarnik?
# 4 2024-04-13 17:48:52.049716     Czy mały książe kochał różę?
#
#                                           Query Text  \
# 0                       Mały Książę tęsknił za różą.
# 1  Obowiązki zarządu obejmują podejmowanie strate...
# 2  Mały książę był postacią, która wykazywała głę...
# 3  Latarnik zajmował się pilnowaniem latarni mors...
# 4                           Mały książę kochał różę.
#
#                                       Query Embedded
# 0  [0.021756764501333237, 0.05153129994869232, -0...
# 1  [-0.0012379350373521447, 0.052696503698825836,...
# 2  [0.020435670390725136, 0.04087134078145027, -0...
# 3  [-0.03579878807067871, 0.0861918106675148, 0.0...
# ...

# %%
log_z_wynikami = pd.read_pickle(PATH_LOG_RESULTS)
log_z_wynikami
# Out:
#                     Timestamp                       User Input  \
# 0  2024-04-13 17:29:09.495476  Czy mały książe tęsknił za różą
# 1  2024-04-13 17:29:09.499416  Czy mały książe tęsknił za różą
# 2  2024-04-13 17:29:09.501896  Czy mały książe tęsknił za różą
# 3  2024-04-13 17:29:09.505397  Czy mały książe tęsknił za różą
# 4  2024-04-13 17:29:09.508345  Czy mały książe tęsknił za różą
# ..                        ...                              ...
# 60 2024-04-13 18:30:13.091059     Czy mały książe kochał różę?
# 61 2024-04-13 18:30:13.093046     Czy mały książe kochał różę?
# 62 2024-04-13 18:30:13.094035     Czy mały książe kochał różę?
# 63 2024-04-13 18:30:13.094531     Czy mały książe kochał różę?
# 64 2024-04-13 18:30:13.095524     Czy mały książe kochał różę?
#
#                       Query Text         Document  Similarity Page  \
# 0   Mały Książę tęsknił za różą.  maly_ksiaze.pdf    0.677013   19
# 1   Mały Książę tęsknił za różą.  maly_ksiaze.pdf    0.658497   50
# ...
